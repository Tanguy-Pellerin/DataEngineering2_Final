# %%
import pandas as pd
import numpy as np
import re
import string
import gensim
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import pickle
#import preprocessor as p
#from sklearn.metrics.pairwise import euclidean_distances
#from nltk.stem import WordNetLemmatizer
#from nltk.tokenize import word_tokenize

# %%
df = pd.read_csv("tweets.csv", usecols=['text', 'id'])
df.head()
# Out:
#                    id                                               text
# 0  784609194234306560    Here is my statement.pic.twitter.com/WAZiGoQqMQ
# 1  785608815962099712  Is this really America? Terrible!pic.twitter.c...
# 2  784840992734064640  The media and establishment want me out of the...
# 3  784767399442653184        Certainly has been an interesting 24 hours!
# 4  785561269571026944  Debate polls look great - thank you!\n#MAGA #A...

# %%
def preprocess_tweet(text):
    # Check characters to see if they are in punctuation
    nopunc = [char for char in text if char not in string.punctuation]
    # Join the characters again to form the string.
    nopunc = ''.join(nopunc)
    # convert text to lower-case
    nopunc = nopunc.lower()
    # remove pic 
    nopunc = re.sub(r'pic.twitter.com/[\w]*',"", nopunc)
    # remove URLs
    nopunc = re.sub('((www\.[^\s]+)|(https?://[^\s]+)|(http?://[^\s]+))', '', nopunc)
    nopunc = re.sub(r'http\S+', '', nopunc)
    # remove special caracters
    nopunc = re.sub(r'\W+', ' ', nopunc)
    # remove usernames
    nopunc = re.sub('@[^\s]+', '', nopunc)
    # remove the # in #hashtag
    nopunc = re.sub(r'#([^\s]+)', r'\1', nopunc)
    #remove punctuation
    nopunc = re.sub(r'[^\w\s]','',nopunc)
    # remove words with only one character
    nopunc =  re.sub(r"\b[a-zA-Z]\b", "", nopunc)
    # remove repeated characters
    nopunc = word_tokenize(nopunc)
    # remove stopwords from final word list
    return [word for word in nopunc if word not in stopwords.words('english')]

# %%
df_text = df.copy()
df_text["clean_text"] = df_text["text"].apply(lambda x: preprocess_tweet([x]))
df_text.head()
# Out:
#                    id                                               text  \
# 0  784609194234306560    Here is my statement.pic.twitter.com/WAZiGoQqMQ
# 1  785608815962099712  Is this really America? Terrible!pic.twitter.c...
# 2  784840992734064640  The media and establishment want me out of the...
# 3  784767399442653184        Certainly has been an interesting 24 hours!
# 4  785561269571026944  Debate polls look great - thank you!\n#MAGA #A...
#
#                                           clean_text
# 0                                        [statement]
# 1                        [really, america, terrible]
# 2  [media, establishment, want, race, badly, neve...
# 3                [certainly, interesting, 24, hours]
# 4  [debate, polls, look, great, thank, maga, amer...

# %%
def clean_words(df):
    df_text = df.copy()
    df_text["clean_text"] = df_text["text"].apply(lambda x: preprocess_tweet([x]))
    return df_text

# %%
def tag_words(df):
    tag_words = [TaggedDocument(d, [i]) for i, d in enumerate(df.clean_text)]
    return tag_words

# %%
tag_words = [TaggedDocument(d, [i]) for i, d in enumerate(df_text.clean_text)]
tag_words
# Out:
# [TaggedDocument(words=['statement'], tags=[0]),
#  TaggedDocument(words=['really', 'america', 'terrible'], tags=[1]),
#  TaggedDocument(words=['media', 'establishment', 'want', 'race', 'badly', 'never', 'drop', 'race', 'never', 'let', 'supporters', 'maga'], tags=[2]),
#  TaggedDocument(words=['certainly', 'interesting', '24', 'hours'], tags=[3]),
#  TaggedDocument(words=['debate', 'polls', 'look', 'great', 'thank', 'maga', 'americafirst'], tags=[4]),
#  TaggedDocument(words=['saying', 'clinton', 'campaign', 'anti', 'catholic', 'bigotry'], tags=[5]),
#  TaggedDocument(words=['thank', 'maga', 'americafirst'], tags=[6]),
#  TaggedDocument(words=['cincinnati', 'ohio', 'tomorrow', 'night', '7', '30pm', 'join', 'ohiovotesearly', 'votetrumppence16', 'tickets'], tags=[7]),
#  TaggedDocument(words=['little', 'pick', 'dishonest', 'media', 'incredible', 'information', 'provided', 'wikileaks', 'dishonest', 'rigged', 'system'], tags=[8]),
#  TaggedDocument(words=['thank', 'florida', 'movement', 'never', 'seen', 'never', 'seen', 'lets', 'get', 'votetrumppence16', '11', '8', 'maga'], tags=[9]),
#  TaggedDocument(words=['foul', 'mouthed', 'sen', 'john', 'mccain', 'begged', 'support', 'primary', 'gave', 'dropped', 'locker', 'room', 'remarks'], tags=[10]),
#  TaggedDocument(words=['disloyal', 'far', 'difficult', 'crooked', 'hillary', 'come', 'sides', 'know', 'win', 'teach'], tags=[11]),
#  TaggedDocument(words=['exception', 'cheating', 'bernie', 'nom', 'dems', 'always', 'proven', 'far', 'loyal', 'republicans'], tags=[12]),
#  TaggedDocument(words=['nice', 'shackles', 'taken', 'fight', 'america', 'way', 'want'], tags=[13]),
#  TaggedDocument(words=['weak', 'ineffective', 'leader', 'paul', 'ryan', 'bad', 'conference', 'call', 'members', 'went', 'wild', 'disloyalty'], tags=[14]),
#  TaggedDocument(words=['despite', 'winning', 'second', 'debate', 'landslide', 'every', 'poll', 'hard', 'well', 'paul', 'ryan', 'others', 'give', 'zero', 'support'], tags=[15]),
#  TaggedDocument(words=['wow', 'cnn', 'got', 'caught', 'fixing', 'focus', 'group', 'order', 'make', 'crooked', 'hillary', 'look', 'better', 'really', 'pathetic', 'totally', 'dishonest'], tags=[16]),
#  TaggedDocument(words=['hillaryclinton', 'law', 'debates2016'], tags=[17]),
#  TaggedDocument(words=['team', 'deplorables', 'taking', 'twitter', 'account', 'tonight', 'debate', 'makeamericagreatagain'], tags=[18]),
#  TaggedDocument(words=['many', 'self', 'righteous', 'hypocrites', 'watch', 'poll', 'numbers', 'elections', 'go'], tags=[19]),
#  TaggedDocument(words=['wow', 'hear', 'bill', 'clinton', 'statement', 'bad', 'obamacare', 'hillary', 'happy', 'saying', 'repeal', 'replace'], tags=[20]),
#  TaggedDocument(words=['watching', 'great', 'governor', 'mike_pence', 'live', 'tweeting', 'vp', 'debate', 'tonight', 'starting', '8', '30pm', 'est', 'enjoy'], tags=[21]),
#  TaggedDocument(words=['announced', 'iraq', 'preparing', 'battle', 'reclaim', 'mosul', 'announce', 'makes', 'mission', 'much', 'harder'], tags=[22]),
#  TaggedDocument(words=['melania', 'extend', 'warmest', 'greetings', 'observing', 'rosh', 'hashanah', 'united', 'states', 'israel', 'around', 'world'], tags=[23]),
#  TaggedDocument(words=['bernie', 'pull', 'endorsement', 'crooked', 'hillary', 'decieved', 'attacked', 'supporters'], tags=[24]),
#  TaggedDocument(words=['trumplican2016', 'realdonaldtrump', 'massive', 'turnout', 'mr', 'trump', 'polls', 'register', 'pulse', 'people'], tags=[25]),
#  TaggedDocument(words=['created', 'tens', 'thousands', 'jobs', 'bring', 'back', 'great', 'american', 'prosperity', 'hillary', 'created', 'jobs', 'fbi', 'doj'], tags=[26]),
#  TaggedDocument(words=['know', 'complex', 'tax', 'laws', 'better', 'anyone', 'ever', 'run', 'president', 'one', 'fix', 'failing', 'nytimes'], tags=[27]),
#  TaggedDocument(words=['wow', 'saw', 'really', 'bad', 'cnn', 'ratings', 'people', 'want', 'watch', 'bad', 'product', 'builds', 'crooked', 'hillary'], tags=[28]),
#  TaggedDocument(words=['called', 'commission', 'presidential', 'debates', 'admitted', 'us', 'djt', 'audio', 'sound', 'level', 'bad', 'fix'], tags=[29]),
#  TaggedDocument(words=['crooked', 'nasty', 'sanders', 'supporters', 'behind', 'closed', 'doors', 'owned', 'wall', 'st', 'politicians', 'hrc'], tags=[30]),
#  TaggedDocument(words=['believe', 'americafirst', 'means', 'family', 'first', 'childcare', 'plan', 'reflects', 'needs', 'modern', 'working', 'class', 'families', 'imwithyou'], tags=[31]),
#  TaggedDocument(words=['people', 'knocking', 'tweeting', 'three', 'clock', 'morning', 'least', 'know', 'awake', 'answer', 'call'], tags=[32]),
#  TaggedDocument(words=['hillary', '50', 'points', 'ahead', 'maybe', 'email', 'scandal', 'policies', 'spread', 'isis', 'calling', 'millions', 'americans', 'deplorables'], tags=[33]),
#  TaggedDocument(words=['people', 'really', 'smart', 'cancelling', 'subscriptions', 'dallas', 'arizona', 'papers', 'usa', 'today', 'lose', 'readers', 'people', 'get'], tags=[34]),
#  TaggedDocument(words=['remember', 'believe', 'sources', 'said', 'dishonest', 'media', 'name', 'sources', 'sources', 'exist'], tags=[35]),
#  TaggedDocument(words=['wow', 'crooked', 'hillary', 'duped', 'used', 'worst', 'miss', 'hillary', 'floated', 'angel', 'without', 'checking', 'past', 'terrible'], tags=[36]),
#  TaggedDocument(words=['anytime', 'see', 'story', 'campaign', 'saying', 'sources', 'said', 'believe', 'sources', 'made', 'lies'], tags=[37]),
#  TaggedDocument(words=['wow', 'see', 'badly', 'cnn', 'clinton', 'news', 'network', 'ratings', 'people', 'like', 'donlemon', 'could', 'expect'], tags=[38]),
#  TaggedDocument(words=['hillary', 'profits', 'rigged', 'system', 'fighting', 'remember', 'simple', 'phrase', 'followthemoney'], tags=[39]),
#  TaggedDocument(words=['condolences', 'involved', 'today', 'horrible', 'accident', 'nj', 'deepest', 'gratitude', 'amazing', 'first', 'responders'], tags=[40]),
#  TaggedDocument(words=['every', 'line', 'poll', 'time', 'magazine', 'drudge', 'etc', 'winning', 'debate', 'thank', 'fox', 'friends', 'reporting'], tags=[41]),
#  TaggedDocument(words=['supporters', 'best', '18', 'million', 'hard', 'working', 'people', 'know', 'shatter', 'record'], tags=[42]),
#  TaggedDocument(words=['unbelievable', 'evening', 'melbourne', 'florida', '15', '000', 'supporters', 'additional', '12', '000', 'could', 'get', 'thank', 'trumptrain', 'maga'], tags=[43]),
#  TaggedDocument(words=['great', 'afternoon', 'little', 'havana', 'hispanic', 'community', 'leaders', 'thank', 'support', 'imwithyou'], tags=[44]),
#  TaggedDocument(words=['last', '24', 'hrs', 'raised', '13m', 'online', 'donations', 'national', 'call', 'day', 'still', 'going', 'thank', 'america', 'maga'], tags=[45]),
#  TaggedDocument(words=['well', 'saying', 'nbc', 'presidential', 'forum', 'last', 'night', 'big', 'debate', 'nice'], tags=[46]),
#  TaggedDocument(words=['thank', 'trumpwon', 'maga'], tags=[47]),
#  TaggedDocument(words=['hillary', 'failing', '30', 'years', 'getting', 'job', 'done', 'never', 'change'], tags=[48]),
#  TaggedDocument(words=['1', 'trend', 'twitter', 'right', 'trumpwon', 'thank'], tags=[49]),
#  TaggedDocument(words=['every', 'poll', 'last', 'nights', 'presidential', 'debate', 'except', 'little', 'watched', 'cnn', 'poll'], tags=[50]),
#  TaggedDocument(words=['trump', 'bar', 'full', 'undecideds', 'democrats'], tags=[51]),
#  TaggedDocument(words=['really', 'enjoyed', 'debate', 'last', 'night', 'crooked', 'hillary', 'says', 'going', 'many', 'things', 'done', 'last', '30', 'years'], tags=[52]),
#  TaggedDocument(words=['thank', 'four', 'new', 'debatenight', 'polls', 'movement', 'winning', 'together', 'make', 'america', 'safe', 'great'], tags=[53]),
#  TaggedDocument(words=['drudge_report', 'first', 'presidential', 'debate', 'poll', 'trump', '80', 'clinton', '20', 'join', 'movement', 'today', 'lets', 'maga'], tags=[54]),
#  TaggedDocument(words=['newtgingrich', 'said', 'historic', 'victory', 'trump', 'nice'], tags=[55]),
#  TaggedDocument(words=['wow', 'great', 'debate', 'polls', 'except', 'cnn', 'watch', 'thank'], tags=[56]),
#  TaggedDocument(words=['thank', 'governor', 'mike_pence', 'lets', 'make', 'america', 'safe', 'great', 'american', 'people', 'americafirst', 'debates2016'], tags=[57]),
#  TaggedDocument(words=['thank', 'senator', 'tedcruz', 'debates2016', 'maga'], tags=[58]),
#  TaggedDocument(words=['russia', 'warheads', 'ever', 'korea', 'testing', 'nukes', 'iran', 'got', 'sweetheart', 'deal', 'keep', 'thanks', 'hillaryclinton'], tags=[59]),
#  TaggedDocument(words=['hillary', 'clinton', 'failed', 'world', 'libya', 'syria', 'iran', 'iraq', 'asia', 'pivot', 'russian', 'reset', 'benghazi', 'debatenight'], tags=[60]),
#  TaggedDocument(words=['stand', 'police', 'protect', 'americans', 'debates2016', 'maga'], tags=[61]),
#  TaggedDocument(words=['simple', 'fact', 'hillaryclinton', 'typical', 'politician', 'talk', 'action', 'debates2016'], tags=[62]),
#  TaggedDocument(words=['hillary', 'bad', 'tax', 'habit'], tags=[63]),
#  TaggedDocument(words=['hillaryclinton', 'part', 'rigged', 'dc', 'system', '30', 'years', 'would', 'take', 'policy', 'advice', 'debates2016'], tags=[64]),
#  TaggedDocument(words=['hillary', 'clinton', '50', 'points', 'ahead', 'debatenight'], tags=[65]),
#  TaggedDocument(words=['team', 'deplorables', 'managing', 'twitter', 'account', 'evenings', 'debate', 'tune', 'debatenight', 'trumppence16'], tags=[66]),
#  TaggedDocument(words=['new', 'national', 'bloomberg', 'poll', 'released', 'thank', 'join', 'movement', 'trumptrain', 'maga'], tags=[67]),
#  TaggedDocument(words=['really', 'sad', 'news', 'great', 'arnold', 'palmer', 'king', 'died', 'one', 'like', 'true', 'champion', 'truly', 'missed'], tags=[68]),
#  TaggedDocument(words=['five', 'people', 'killed', 'washington', 'state', 'middle', 'eastern', 'immigrant', 'many', 'people', 'died', 'weekend', 'ohio', 'drug', 'overdoses', 'riots'], tags=[69]),
#  TaggedDocument(words=['readout', 'meeting', 'israeli', 'prime', 'minister', 'benjamin', 'netanyahu'], tags=[70]),
#  TaggedDocument(words=['looking', 'forward', 'meeting', 'benjamin', 'netanyahu', 'trump', 'tower', '10', '00'], tags=[71]),
#  TaggedDocument(words=['bernie', 'sanders', 'gave', 'hillary', 'dem', 'nomination', 'gave', 'mails', 'issue', 'gotten', 'bigger'], tags=[72]),
#  TaggedDocument(words=['many', 'team', 'staff', 'bernie', 'sanders', 'treated', 'badly', 'hillary', 'clinton', 'campaign', 'like', 'trump', 'trade', 'lot'], tags=[73]),
#  TaggedDocument(words=['dopey', 'mark', 'cuban', 'failed', 'benefactor', 'fame', 'wants', 'sit', 'front', 'row', 'perhaps', 'put', 'gennifer', 'flowers', 'right', 'alongside'], tags=[74]),
#  TaggedDocument(words=['kellyannepolls', 'trump', 'headed', 'win', 'says', 'professor', 'predicted', '30', 'years', 'presidential', 'outcomes'], tags=[75]),
#  TaggedDocument(words=['sentedcruz', 'endorsement', 'wonderful', 'surprise', 'greatly', 'appreciate', 'support', 'tremendous', 'victory', 'november', '8th'], tags=[76]),
#  TaggedDocument(words=['crooked', 'hillary', 'bad', 'judgement', 'forced', 'announce', 'would', 'go', 'charlotte', 'saturday', 'grandstand', 'dem', 'pols', 'said', 'way', 'dumb'], tags=[77]),
#  TaggedDocument(words=['spoke', 'governor', 'patmccrorync', 'north', 'carolina', 'today', 'tremendous', 'job', 'tough', 'circumstances'], tags=[78]),
#  TaggedDocument(words=['great', 'new', 'polls', 'thank', 'nevada', 'north', 'carolina', 'ohio', 'join', 'movement', 'today', 'lets', 'maga'], tags=[79]),
#  TaggedDocument(words=['hopefully', 'violence', 'unrest', 'charlotte', 'come', 'immediate', 'end', 'injured', 'get', 'well', 'soon', 'need', 'unity', 'leadership'], tags=[80]),
#  TaggedDocument(words=['situations', 'tulsa', 'charlotte', 'tragic', 'must', 'come', 'together', 'make', 'america', 'safe'], tags=[81]),
#  TaggedDocument(words=['movement', 'campaign', 'leaving', 'past', 'behind', 'changing', 'future', 'together', 'make', 'america', 'safe', 'great'], tags=[82]),
#  TaggedDocument(words=['thank', 'kenansville', 'north', 'carolina', 'remember', 'november', '8th', 'special', 'interest', 'gravy', 'train', 'coming', 'abrupt', 'end', 'maga'], tags=[83]),
#  TaggedDocument(words=['thank', 'high', 'point', 'nc', 'fight', 'every', 'neglected', 'part', 'nation', 'fight', 'bring', 'us', 'together', 'one', 'american', 'people'], tags=[84]),
#  TaggedDocument(words=['hillary', 'clinton', 'taking', 'day', 'needs', 'rest', 'sleep', 'well', 'hillary', 'see', 'debate'], tags=[85]),
#  TaggedDocument(words=['people', 'notice', 'hillary', 'copying', 'airplane', 'rallies', 'puts', 'plane', 'behind', 'like', 'beginning'], tags=[86]),
#  TaggedDocument(words=['crooked', 'hillary', 'fighting', 'isis', 'whatever', 'years', 'new', 'ideas', 'time', 'change'], tags=[87]),
#  TaggedDocument(words=['together', 'make', 'america', 'safe', 'great', 'imwithyou', 'americafirst'], tags=[88]),
#  TaggedDocument(words=['hillary', 'clinton', 'weakness', 'secretary', 'state', 'emboldened', 'terrorists', 'world', 'cont'], tags=[89]),
#  TaggedDocument(words=['someone', 'told', 'ok', 'turns', 'terrorist', 'wants', 'destroy', 'country', 'people', 'get', 'thru', 'system'], tags=[90]),
#  TaggedDocument(words=['great', 'job', 'law', 'enforcement', 'proud', 'embrace', 'without', 'country'], tags=[91]),
#  TaggedDocument(words=['terrible', 'attacks', 'ny', 'nj', 'mn', 'weekend', 'thinking', 'victims', 'families', 'americans', 'need', 'strong'], tags=[92]),
#  TaggedDocument(words=['leadership', 'obama', 'clinton', 'americans', 'experienced', 'attacks', 'home', 'victories', 'abroad', 'time', 'change', 'playbook'], tags=[93]),
#  TaggedDocument(words=['happy', 'birthday', 'united', 'states', 'air', 'force'], tags=[94]),
#  TaggedDocument(words=['would', 'like', 'express', 'warmest', 'regards', 'best', 'wishes', 'condolences', 'families', 'victims', 'horrible', 'bombing', 'nyc'], tags=[95]),
#  TaggedDocument(words=['lawyers', 'want', 'sue', 'failing', 'nytimes', 'badly', 'irresponsible', 'intent', 'said', 'watching', 'really', 'disgusting'], tags=[96]),
#  TaggedDocument(words=['failing', 'nytimes', 'gone', 'nuts', 'crooked', 'hillary', 'badly', 'willing', 'say', 'anything', 'become', 'laughingstock', 'rag'], tags=[97]),
#  TaggedDocument(words=['wacky', 'nytimesdowd', 'hardly', 'knows', 'makes', 'things', 'never', 'said', 'boring', 'interviews', 'column', 'neurotic', 'dope'], tags=[98]),
#  TaggedDocument(words=['cnn', 'get', 'ratings', 'low', 'getting', 'worse', 'boring', 'anti', 'trump', 'panelists', 'mostly', 'losers', 'life'], tags=[99]),
#  TaggedDocument(words=['never', 'met', 'former', 'defense', 'secretary', 'robert', 'gates', 'knows', 'nothing', 'look', 'results', 'guidance', 'total', 'disaster'], tags=[100]),
#  TaggedDocument(words=['crooked', 'hillary', 'wants', 'take', '2nd', 'amendment', 'rights', 'away', 'guns', 'taken', 'heavily', 'armed', 'secret', 'service', 'detail', 'maybe'], tags=[101]),
#  TaggedDocument(words=['thoughts', 'prayers', 'go', 'phillypolice', 'penn', 'police', 'officers', 'philadelphia'], tags=[102]),
#  TaggedDocument(words=['donald', 'trump', 'birther', 'event', 'greatest', 'trick', 'ever', 'pulled'], tags=[103]),
#  TaggedDocument(words=['arrived', 'texas', 'informed', 'two', 'fortworthpd', 'officers', 'shot', 'thoughts', 'prayers'], tags=[104]),
#  TaggedDocument(words=['leaving', 'miami', 'houston', 'oklahoma', 'colorado', 'miami', 'crowd', 'fantastic'], tags=[105]),
#  TaggedDocument(words=['great', 'parade', 'villages', 'love', 'maga', 'thank', 'incredible', 'support', 'forget'], tags=[106]),
#  TaggedDocument(words=['truly', 'honored', 'grateful', 'receiving', 'much', 'support', 'american', 'heroes'], tags=[107]),
#  TaggedDocument(words=['going', 'brand', 'new', 'trump', 'international', 'hotel', 'major', 'statement'], tags=[108]),
#  TaggedDocument(words=['instead', 'driving', 'jobs', 'wealth', 'away', 'america', 'become', 'world', 'great', 'magnet', 'innovation', 'job', 'creation'], tags=[109]),
#  TaggedDocument(words=['thank', 'law', 'enforcement', 'officers', 'across', 'america', 'lesm', 'maga'], tags=[110]),
#  TaggedDocument(words=['never', 'fan', 'colin', 'powell', 'weak', 'understanding', 'weapons', 'mass', 'destruction', 'iraq', 'disaster', 'much', 'better'], tags=[111]),
#  TaggedDocument(words=['great', 'poll', 'nevada', 'thank', 'see', 'soon', 'maga', 'americafirst'], tags=[112]),
#  TaggedDocument(words=['great', 'evening', 'canton', 'ohio', 'thank', 'going', 'make', 'america', 'great', 'join', 'us'], tags=[113]),
#  TaggedDocument(words=['thank', 'ohio', 'landed', 'canton', 'rally', 'civic', 'center', 'join', '7pm'], tags=[114]),
#  TaggedDocument(words=['thank', 'florida', 'wait', 'see', 'friday', 'miami', 'join'], tags=[115]),
#  TaggedDocument(words=['great', 'poll', 'florida', 'thank', 'imwithyou', 'americafirst'], tags=[116]),
#  TaggedDocument(words=['thank', 'ohio', 'see', 'tonight'], tags=[117]),
#  TaggedDocument(words=['russia', 'took', 'crimea', 'called', 'obama', 'years', 'know', 'obama', 'get', 'free', 'pass'], tags=[118]),
#  TaggedDocument(words=['president', 'obama', 'working', 'instead', 'campaigning', 'hillary', 'clinton'], tags=[119]),
#  TaggedDocument(words=['got', 'back', 'asheville', 'north', 'carolina', 'massive', 'rally', 'spirit', 'crowd', 'unbelievable', 'thank', 'maga'], tags=[120]),
#  TaggedDocument(words=['stopped', 'trumpdc', 'thank', 'tremendous', 'men', 'women', 'hard', 'work'], tags=[121]),
#  TaggedDocument(words=['seriously', 'failing', 'nytimes', 'despite', 'much', 'winning', 'poll', 'numbers', 'soon', 'put', 'first', 'place', 'writes', 'dishonest', 'hits'], tags=[122]),
#  TaggedDocument(words=['hillary', 'clinton', '47', 'moment', 'terrible', 'thing', 'said', 'many', 'great', 'americans'], tags=[123]),
#  TaggedDocument(words=['hillary', 'said', 'horrible', 'things', 'supporters', 'many', 'supporters', 'never', 'vote', 'still', 'respect'], tags=[124]),
#  TaggedDocument(words=['really', 'sad', 'republicans', 'would', 'allow', 'used', 'clinton', 'ad', 'lindsey', 'graham', 'romney', 'flake', 'sass', 'supreme', 'court', 'remember'], tags=[125]),
#  TaggedDocument(words=['wow', 'hillary', 'clinton', 'insulting', 'supporters', 'millions', 'amazing', 'hard', 'working', 'people', 'think', 'cost', 'polls'], tags=[126]),
#  TaggedDocument(words=['missouri', 'today', 'melania', 'funeral', 'wonderful', 'truly', 'respected', 'woman', 'phyllis'], tags=[127]),
#  TaggedDocument(words=['thank', 'ohio', 'together', 'make', 'america', 'great'], tags=[128]),
#  TaggedDocument(words=['great', 'honor', 'endorsed', 'popular', 'successful', 'gov_gilmore', 'va', 'state', 'much', 'want', 'win', 'thx', 'jim'], tags=[129]),
#  TaggedDocument(words=['make', 'america', 'great', 'americafirst', 'imwithyou'], tags=[130]),
#  TaggedDocument(words=['cnn', 'unwatchable', 'news', 'fiction', 'disgrace', 'broadcasting', 'industry', 'arm', 'clinton', 'campaign'], tags=[131]),
#  TaggedDocument(words=['documentary', 'cnn', 'aired', 'total', 'waste', 'time', 'even', 'know', 'many', 'people', 'spoke', 'joke'], tags=[132]),
#  TaggedDocument(words=['final', 'poll', 'results', 'nbc', 'last', 'nights', 'commander', 'chief', 'forum', 'thank', 'imwithyou', 'maga'], tags=[133]),
#  TaggedDocument(words=['matt', 'lauer', 'hurt', 'hillary', 'last', 'night', 'dumb', 'answer', 'emails', 'veteran', 'said', 'jail'], tags=[134]),
#  TaggedDocument(words=['poll', 'results', 'last', 'nights', 'commander', 'chief', 'forum', 'americafirst', 'trumptrain'], tags=[135]),
#  TaggedDocument(words=['hillary', 'clinton', 'answered', 'email', 'questions', 'differently', 'last', 'night', 'past', 'totally', 'confused', 'unfit', 'serve', 'potus'], tags=[136]),
#  TaggedDocument(words=['hillary', 'gave', 'disastrous', 'news', 'conference', 'tarmac', 'make', 'poor', 'performance', 'last', 'night', 'decimated', 'media'], tags=[137]),
#  TaggedDocument(words=['rough', 'night', 'hillary', 'clinton', 'abc', 'news'], tags=[138]),
#  TaggedDocument(words=['thank', 'america', 'great', 'commanderinchiefforum', 'polls'], tags=[139]),
#  TaggedDocument(words=['thank', 'fantastic', 'veterans', 'reviews', 'polls', 'almost', 'everyone', 'commander', 'chief', 'presentation', 'great', 'nice'], tags=[140]),
#  TaggedDocument(words=['thank', 'peter', 'elected', 'think', 'big', 'country', 'never', 'let', 'american', 'people', 'americafirst'], tags=[141]),
#  TaggedDocument(words=['wow', 'thank', 'pensacola', 'fl', 'see', 'friday', '7pm', 'join'], tags=[142]),
#  TaggedDocument(words=['donald', 'trump', 'leads', 'hillary', 'clinton', '19', 'points', 'among', 'military', 'veteran', 'voters', 'poll', 'americafirst', 'maga'], tags=[143]),
#  TaggedDocument(words=['thank', 'amazing', 'military', 'families', 'service', 'members', 'veterans', 'imwithyou'], tags=[144]),
#  TaggedDocument(words=['thank', 'votetrump', 'imwithyou'], tags=[145]),
#  TaggedDocument(words=['mainstream', 'media', 'never', 'covered', 'hillary', 'massive', 'hacking', 'coughing', 'attack', 'yet', '1', 'trending'], tags=[146]),
#  TaggedDocument(words=['thank', 'americafirst'], tags=[147]),
#  TaggedDocument(words=['china', 'provide', 'red', 'carpet', 'stairway', 'air', 'force', 'one', 'philippines', 'president', 'calls', 'obama', 'son', 'whore', 'terrible'], tags=[148]),
#  TaggedDocument(words=['truly', 'great', 'phyllis', 'schlafly', 'honored', 'strong', 'endorsement', 'president', 'passed', 'away', '92', 'special'], tags=[149]),
#  TaggedDocument(words=['heading', 'youngstown', 'ohio', 'great', 'polls', 'americafirst'], tags=[150]),
#  TaggedDocument(words=['believe', 'chinese', 'would', 'give', 'obama', 'proper', 'stairway', 'get', 'plane', 'fight', 'tarmac'], tags=[151]),
#  TaggedDocument(words=['president', 'obama', 'putin', 'fail', 'reach', 'deal', 'syria', 'else', 'new', 'obama', 'natural', 'deal', 'maker', 'makes', 'bad', 'deals'], tags=[152]),
#  TaggedDocument(words=['lyin', 'hillary', 'clinton', 'told', 'fbi', 'know', 'markings', 'documents', 'stood', 'classified', 'happening'], tags=[153]),
#  TaggedDocument(words=['african', 'american', 'community', 'democrats', 'failed', 'fifty', 'years', 'high', 'crime', 'poor', 'schools', 'jobs', 'fix', 'vote'], tags=[154]),
#  TaggedDocument(words=['polls', 'close', 'crooked', 'hillary', 'getting', 'bed', 'campaign', 'tomorrow', 'hammer', '13', 'devices', 'acid', 'wash', 'mails'], tags=[155]),
#  TaggedDocument(words=['wow', 'failing', 'nytimes', 'reported', 'properly', 'crooked', 'fbi', 'release', 'back', 'pack', 'longer', 'credible', 'source'], tags=[156]),
#  TaggedDocument(words=['cnn', 'disgusting', 'bias', 'hard', 'time', 'promoting', 'crooked', 'hillary', 'light', 'new', 'mail', 'scandals'], tags=[157]),
#  TaggedDocument(words=['great', 'visit', 'detroit', 'church', 'fantastic', 'reception', 'cnn', 'talks', 'small', 'protest', 'outside', 'inside', 'large', 'wonderful', 'crowd'], tags=[158]),
#  TaggedDocument(words=['thank', 'great', 'faith', 'ministries', 'international', 'bishop', 'wayne', 'jackson', 'detroit'], tags=[159]),
#  TaggedDocument(words=['great', 'new', 'poll', 'iowa', 'thank', 'makeamericagreatagain', 'imwithyou'], tags=[160]),
#  TaggedDocument(words=['visited', 'trump', 'tower', 'campaign', 'headquarters', 'last', 'night', 'returning', 'ohio', 'arizona', 'packed', 'great', 'pros', 'win'], tags=[161]),
#  TaggedDocument(words=['people', 'surprised', 'ground', 'game', 'nov', '8', 'army', 'volunteers', 'people', 'great', 'spirit', 'want', 'maga'], tags=[162]),
#  TaggedDocument(words=['promising', 'new', 'legacy', 'america', 'going', 'create', 'new', 'american', 'future', 'thank', 'ohio', 'imwithyou'], tags=[163]),
#  TaggedDocument(words=['poll', 'numbers', 'way', 'making', 'big', 'progress'], tags=[164]),
#  TaggedDocument(words=['thank', 'foxandfriends', 'great', 'review', 'speech', 'immigration', 'last', 'night', 'thank', 'also', 'great', 'people', 'arizona'], tags=[165]),
#  TaggedDocument(words=['mexico', 'pay', 'wall'], tags=[166]),
#  TaggedDocument(words=['trump', 'administration', 'called', 'americafirst', 'imwithyou'], tags=[167]),
#  TaggedDocument(words=['great', 'trip', 'mexico', 'today', 'wonderful', 'leadership', 'high', 'quality', 'people', 'look', 'forward', 'next', 'meeting'], tags=[168]),
#  TaggedDocument(words=['hillary', 'clinton', 'go', 'louisiana', 'go', 'mexico', 'drive', 'stamina', 'make', 'america', 'great'], tags=[169]),
#  TaggedDocument(words=['former', 'president', 'vicente', 'fox', 'railing', 'visit', 'mexico', 'today', 'also', 'invited', 'apologized', 'using', 'bomb'], tags=[170]),
#  TaggedDocument(words=['thank', 'washington', 'together', 'make', 'america', 'safe', 'great', 'imwithyou', 'americafirst'], tags=[171]),
#  TaggedDocument(words=['accepted', 'invitation', 'president', 'enrique', 'pena', 'nieto', 'mexico', 'look', 'much', 'forward', 'meeting', 'tomorrow'], tags=[172]),
#  TaggedDocument(words=['thank', 'north', 'carolina', 'maga'], tags=[173]),
#  TaggedDocument(words=['day', 'one', 'said', 'going', 'build', 'great', 'wall', 'southern', 'border', 'much', 'stop', 'illegal', 'immigration', 'watch', 'wednesday'], tags=[174]),
#  TaggedDocument(words=['repeal', 'replace', 'horrible', 'disaster', 'known', 'obamacare'], tags=[175]),
#  TaggedDocument(words=['african', 'americans', 'seeing', 'bad', 'job', 'hillary', 'type', 'policy', 'management', 'done', 'inner', 'cities', 'want', 'trump'], tags=[176]),
#  TaggedDocument(words=['anyone', 'know', 'crooked', 'hillary', 'tried', 'hard', 'unable', 'pass', 'bar', 'exams', 'washington', 'forced', 'go', 'elsewhere'], tags=[177]),
#  TaggedDocument(words=['making', 'major', 'speech', 'illegal', 'immigration', 'wednesday', 'great', 'state', 'arizona', 'big', 'crowds', 'looking', 'larger', 'venue'], tags=[178]),
#  TaggedDocument(words=['think', 'candidates', 'crooked', 'hillary', 'release', 'detailed', 'medical', 'records', 'problem', 'hillary'], tags=[179]),
#  TaggedDocument(words=['today', '53rd', 'anniversary', 'march', 'washington', 'today', 'honor', 'enduring', 'fight', 'justice', 'equality', 'opportunity'], tags=[180]),
#  TaggedDocument(words=['national', 'debt', 'january', '2009', '10', '6', 'trillion', 'august', '2016', '19', '4', 'trillion'], tags=[181]),
#  TaggedDocument(words=['honor', 'amazing', 'root', 'family', 'join', 'iowa', 'inspired', 'courage', 'bravery'], tags=[182]),
#  TaggedDocument(words=['condolences', 'dwyane', 'wade', 'family', 'loss', 'nykea', 'aldridge', 'thoughts', 'prayers'], tags=[183]),
#  TaggedDocument(words=['dwyane', 'wade', 'cousin', 'shot', 'killed', 'walking', 'baby', 'chicago', 'saying', 'african', 'americans', 'vote', 'trump'], tags=[184]),
#  TaggedDocument(words=['diamondandsilk', 'crooked', 'hillary', 'getting', 'desperate', 'tv', 'bashing', 'trump', 'cnn', 'forgot', 'said', 'kkk', 'member', 'mentor'], tags=[185]),
#  TaggedDocument(words=['heroin', 'overdoses', 'taking', 'children', 'others', 'midwest', 'coming', 'southern', 'border', 'need', 'strong', 'border', 'wall'], tags=[186]),
#  TaggedDocument(words=['new', 'polls', 'join', 'movement', 'today', 'imwithyou'], tags=[187]),
#  TaggedDocument(words=['phoenix', 'arizona', 'wednesday', 'changing', 'venue', 'much', 'larger', 'one', 'demand', 'unreal', 'polls', 'looking', 'great', 'imwithyou'], tags=[188]),
#  TaggedDocument(words=['quickly', 'people', 'forget', 'crooked', 'hillary', 'called', 'african', 'american', 'youth', 'super', 'predators', 'apologized'], tags=[189]),
#  TaggedDocument(words=['proud', 'brought', 'subject', 'illegal', 'immigration', 'back', 'discussion', 'big', 'problem', 'country', 'solve'], tags=[190]),
#  TaggedDocument(words=['african', 'americans', 'hispanics', 'lose', 'going', 'look', 'poverty', 'crime', 'educational', 'statistics', 'fix'], tags=[191]),
#  TaggedDocument(words=['crooked', 'hillary', 'never', 'able', 'solve', 'problems', 'poverty', 'education', 'safety', 'within', 'african', 'american', 'hispanic', 'communities'], tags=[192]),
#  TaggedDocument(words=['hillary', 'clinton', 'needs', 'address', 'racist', 'undertones', '2008', 'campaign', 'flashbackfriday'], tags=[193]),
#  TaggedDocument(words=['hillary', 'clinton', 'knows', 'make', 'speech', 'hit', 'policy', 'always', 'short', 'stamina', 'media', 'gives', 'pass'], tags=[194]),
#  TaggedDocument(words=['hrc', 'using', 'oldest', 'play', 'dem', 'playbook', 'policies', 'fail', 'left', 'one', 'tired', 'argument'], tags=[195]),
#  TaggedDocument(words=['hillary', 'clinton', 'using', 'race', 'baiting', 'try', 'get', 'african', 'american', 'voters', 'know', 'talk', 'action'], tags=[196]),
#  TaggedDocument(words=['hillary', 'clinton', 'short', 'speech', 'pandering', 'worst', 'instincts', 'society', 'ashamed'], tags=[197]),
#  TaggedDocument(words=['watched', 'recap', 'crookedhillary', 'speech', 'short', 'lies', 'one', 'fear', 'mongering'], tags=[198]),
#  TaggedDocument(words=['many', 'african', 'american', 'community', 'badly', 'poverty', 'crime', 'way', 'employment', 'jobs', 'way', 'fix', 'promise'], tags=[199]),
#  TaggedDocument(words=['poll', 'numbers', 'starting', 'look', 'good', 'leading', 'florida', 'cnn', 'arizona', 'big', 'jump', 'utah', 'numbers', 'rising', 'national', 'way', 'wow'], tags=[200]),
#  TaggedDocument(words=['thoughts', 'prayers', 'great', 'people', 'indiana', 'prevail'], tags=[201]),
#  TaggedDocument(words=['great', 'governor', 'mike_pence', 'indiana', 'help', 'lead', 'relief', 'efforts', 'tornadoes', 'struck', 'true', 'leadership'], tags=[202]),
#  TaggedDocument(words=['great', 'new', 'poll', 'florida', 'thank', 'makeamericagreatagain'], tags=[203]),
#  TaggedDocument(words=['thoughts', 'prayers', 'victims', 'families', 'affected', 'two', 'powerful', 'earthquakes', 'italy', 'myanmar'], tags=[204]),
#  TaggedDocument(words=['thank', 'travis', 'county', 'texas', 'makeamericagreatagain'], tags=[205]),
#  TaggedDocument(words=['austin', 'texas', 'amazing', 'border', 'patrol', 'agents', 'let'], tags=[206]),
#  TaggedDocument(words=['president', 'obama', 'gone', 'louisiana', 'days', 'ago', 'instead', 'golfing', 'little', 'late'], tags=[207]),
#  TaggedDocument(words=['reported', 'virtually', 'everyone', 'fact', 'media', 'pile', 'worst', 'american', 'political', 'history'], tags=[208]),
#  TaggedDocument(words=['anncoulter', 'new', 'book', 'trump', 'trust', 'comes', 'tomorrow', 'people', 'saying', 'terrific', 'knowing', 'ann', 'sure'], tags=[209]),
#  TaggedDocument(words=['leaving', 'akron', 'ohio', 'packed', 'rally', 'amazing', 'people', 'going', 'texas'], tags=[210]),
#  TaggedDocument(words=['great', 'meeting', 'active', 'retired', 'law', 'enforcement', 'officers', 'fraternal', 'order', 'police', 'lodge', 'akron', 'ohio'], tags=[211]),
#  TaggedDocument(words=['day', 'things', 'calm', 'tell', 'real', 'story', 'joenbc', 'insecure', 'long', 'time', 'girlfriend', 'morningmika', 'two', 'clowns'], tags=[212]),
#  TaggedDocument(words=['crooked', 'hillary', 'flooding', 'airwaves', 'false', 'misleading', 'ads', 'paid', 'bosses', 'wall', 'street', 'media', 'protecting'], tags=[213]),
#  TaggedDocument(words=['drawing', 'big', 'enthusiastic', 'crowds', 'media', 'refuses', 'show', 'discuss', 'something', 'big', 'happening'], tags=[214]),
#  TaggedDocument(words=['together', 'going', 'make', 'america', 'safe', 'great'], tags=[215]),
#  TaggedDocument(words=['bring', 'america', 'together', 'one', 'country', 'united', 'americans', 'common', 'purpose', 'common', 'dreams', 'maga'], tags=[216]),
#  TaggedDocument(words=['catonglass', '200', '000', 'new', 'followers', 'realdonaldtrump', '10', '800', '000', '11', '000', '000', 'last', 'ten', 'days', 'maga', 'alwaystrump'], tags=[217]),
#  TaggedDocument(words=['franklin_graham', 'billynungesser', 'samaritanspurse', 'humbled', 'time', 'thoughts', 'prayers'], tags=[218]),
#  TaggedDocument(words=['one', 'nation', 'one', 'hurts', 'hurt', 'must', 'work', 'together', 'lift', 'standwithlouisiana'], tags=[219]),
#  TaggedDocument(words=['whereshillary', 'sleeping'], tags=[220]),
#  TaggedDocument(words=['thank', 'michigan', 'movement', 'going', 'make', 'america', 'safe', 'great', 'trumppence16'], tags=[221]),
#  TaggedDocument(words=['thank', 'everyone', 'nice', 'comments', 'twitter', 'pundits', 'otherwise', 'speech', 'last', 'night'], tags=[222]),
#  TaggedDocument(words=['soon', 'calling', 'mr', 'brexit'], tags=[223]),
#  TaggedDocument(words=['going', 'make', 'government', 'people', 'makeamericagreatagain', 'imwithyou'], tags=[224]),
#  TaggedDocument(words=['repeal', 'replace', 'obamacare', 'caused', 'soaring', 'double', 'digit', 'premium', 'increases', 'disaster'], tags=[225]),
#  TaggedDocument(words=['vote', 'hillary', 'clinton', 'vote', 'another', 'generation', 'poverty', 'high', 'crime', 'lost', 'opportunities', 'imwithyou'], tags=[226]),
#  TaggedDocument(words=['another', 'health', 'insurer', 'pulling', 'back', 'due', 'persistent', 'financial', 'losses', 'obamacare', 'plans', 'beginning'], tags=[227]),
#  TaggedDocument(words=['clinton', 'refugee', 'plan', 'could', 'bring', '620', '000', 'refugees', 'first', 'term', 'lifetime', 'cost', '400', 'billion'], tags=[228]),
#  TaggedDocument(words=['certain', 'republicans', 'lost', 'would', 'rather', 'save', 'face', 'fighting', 'see', 'supreme', 'court', 'get', 'proper', 'appointments', 'sad'], tags=[229]),
#  TaggedDocument(words=['stay', 'message', 'chant', 'always', 'trade', 'jobs', 'military', 'vets', '2nd', 'repeal', 'ocare', 'borders', 'etc', 'media', 'misrepresents'], tags=[230]),
#  TaggedDocument(words=['always', 'person', 'remain', 'true', 'self', 'media', 'wants', 'change', 'would', 'dishonest', 'supporters'], tags=[231]),
#  TaggedDocument(words=['freedom', 'press', 'newspapers', 'others', 'allowed', 'say', 'write', 'whatever', 'want', 'even', 'completely', 'false'], tags=[232]),
#  TaggedDocument(words=['fighting', 'crooked', 'hillary', 'fighting', 'dishonest', 'corrupt', 'media', 'government', 'protection', 'process', 'people', 'get'], tags=[233]),
#  TaggedDocument(words=['crooked', 'hillary', 'clinton', 'protected', 'media', 'talented', 'person', 'politician', 'dishonest', 'media', 'refuses', 'expose'], tags=[234]),
#  TaggedDocument(words=['rallies', 'covered', 'properly', 'media', 'never', 'discuss', 'real', 'message', 'never', 'show', 'crowd', 'size', 'enthusiasm'], tags=[235]),
#  TaggedDocument(words=['disgusting', 'corrupt', 'media', 'covered', 'honestly', 'put', 'false', 'meaning', 'words', 'say', 'would', 'beating', 'hillary', '20'], tags=[236]),
#  TaggedDocument(words=['failing', 'nytimes', 'never', 'spoke', 'keeps', 'saying', 'saying', 'advisers', 'change', 'false', 'never', 'said'], tags=[237]),
#  TaggedDocument(words=['failing', 'nytimes', 'talks', 'anonymous', 'sources', 'meetings', 'never', 'happened', 'reporting', 'fiction', 'media', 'protects', 'hillary'], tags=[238]),
#  TaggedDocument(words=['confirmation', 'one', 'reason', 'crooked', 'wanted', 'sure', 'nobody', 'saw', 'mails', 'pay', 'play', 'run', 'pres'], tags=[239]),
#  TaggedDocument(words=['truly', 'enjoying', 'running', 'president', 'people', 'country', 'amazing', 'great', 'numbers', 'november', '8th'], tags=[240]),
#  TaggedDocument(words=['failing', 'nytimes', 'become', 'newspaper', 'fiction', 'stories', 'always', 'quote', 'non', 'existent', 'unnamed', 'sources', 'dishonest'], tags=[241]),
#  TaggedDocument(words=['thank', 'erie', 'pennsylvania', 'together', 'makeamericagreatagain'], tags=[242]),
#  TaggedDocument(words=['isis', 'gained', 'tremendous', 'strength', 'hillary', 'clinton', 'term', 'secretary', 'state', 'dishonest', 'media', 'report', 'facts'], tags=[243]),
#  TaggedDocument(words=['love', 'watching', 'poor', 'pathetic', 'people', 'pundits', 'television', 'working', 'hard', 'seriously', 'try', 'figure'], tags=[244]),
#  TaggedDocument(words=['massive', 'tax', 'increase', 'necessary', 'fund', 'crooked', 'hillary', 'clinton', 'agenda', 'terrible', 'boring', 'rollout', 'yesterday'], tags=[245]),
#  TaggedDocument(words=['ratings', 'challenged', 'cnn', 'reports', 'seriously', 'call', 'president', 'obama', 'clinton', 'founder', 'isis', 'mvp', 'get', 'sarcasm'], tags=[246]),
#  TaggedDocument(words=['elsolarverde', 'corrupt', 'media', 'creats', 'controversy', 'realdonaldtrump', 'avoid', 'issues', 'hillaryclinton'], tags=[247]),
#  TaggedDocument(words=['surprise', 'constant', 'phony', 'reporting', 'failing', 'cnn', 'turns', 'everyone', 'american', 'people', 'get'], tags=[248]),
#  TaggedDocument(words=['thank', 'fort', 'lauderdale', 'florida', 'makeamericagreatagain'], tags=[249]),
#  TaggedDocument(words=['great', 'job', 'today', 'nypd', 'protecting', 'people', 'saving', 'climber'], tags=[250]),
#  TaggedDocument(words=['reuters', 'announced', 'secret', 'service', 'never', 'spoke', 'campaign', 'made', 'story', 'cnn', 'hoax', 'totally', 'dishonest'], tags=[251]),
#  TaggedDocument(words=['thoughts', 'prayers', 'two', 'police', 'officers', 'shot', 'sebastian', 'county', 'arkansas', 'lesm'], tags=[252]),
#  TaggedDocument(words=['dbongino', 'fantastic', 'defending', 'second', 'amendment', 'last', 'night', 'cnn', 'lemon', 'lightweight', 'dumb', 'rock'], tags=[253]),
#  TaggedDocument(words=['media', 'desperate', 'distract', 'clinton', 'anti', '2a', 'stance', 'said', 'pro', '2a', 'citizens', 'must', 'organize', 'get', 'vote', 'save', 'constitution'], tags=[254]),
#  TaggedDocument(words=['media', 'going', 'talk', 'hillary', 'policies', 'gotten', 'people', 'killed', 'like', 'libya', 'open', 'borders', 'maybe', 'emails'], tags=[255]),
#  TaggedDocument(words=['thank', 'wilmington', 'north', 'carolina', 'makeamericagreatagain'], tags=[256]),
#  TaggedDocument(words=['running', 'washington', 'insiders', 'like', 'republican', 'primaries', 'people', 'made', 'mess'], tags=[257]),
#  TaggedDocument(words=['detroit', 'today', 'wonderful', 'quick', 'stop', 'ohio', 'meet', 'great', 'supporters', 'got', 'back', 'home'], tags=[258]),
#  TaggedDocument(words=['many', 'people', 'saying', 'iranians', 'killed', 'scientist', 'helped', 'hillary', 'clinton', 'hacked', 'emails'], tags=[259]),
#  TaggedDocument(words=['thank', 'newt'], tags=[260]),
#  TaggedDocument(words=['icymi', 'media', 'apologize', 'trump'], tags=[261]),
#  TaggedDocument(words=['michael', 'morell', 'lightweight', 'former', 'acting', 'director', 'man', 'made', 'serious', 'bad', 'calls', 'total', 'clinton', 'flunky'], tags=[262]),
#  TaggedDocument(words=['media', 'going', 'crazy', 'totally', 'distort', 'many', 'things', 'purpose', 'crimea', 'nuclear', 'baby', 'much', 'dishonest'], tags=[263]),
#  TaggedDocument(words=['see', 'mayor', 'stephanie', 'rawlings', 'blake', 'baltimore', 'pushing', 'crooked', 'hard', 'look', 'job', 'done', 'baltimore', 'joke'], tags=[264]),
#  TaggedDocument(words=['larry_kudlow', 'donald', 'trump', 'middle', 'class', 'growth', 'candidate'], tags=[265]),
#  TaggedDocument(words=['running', 'crooked', 'hillary', 'clinton', 'running', 'dishonest', 'totally', 'biased', 'media', 'win'], tags=[266]),
#  TaggedDocument(words=['heading', 'new', 'hampshire', 'talking', 'hillary', 'saying', 'brain', 'short', 'circuited', 'things'], tags=[267]),
#  TaggedDocument(words=['anybody', 'whose', 'mind', 'short', 'circuits', 'fit', 'president', 'look', 'word', 'brainwashed'], tags=[268]),
#  TaggedDocument(words=['crooked', 'hillary', 'said', 'loudly', 'world', 'see', 'short', 'circuited', 'answering', 'question', 'mails', 'dangerous'], tags=[269]),
#  TaggedDocument(words=['hillary', 'clinton', 'badly', 'criticized', 'poor', 'performance', 'answering', 'questions', 'let', 'us', 'see', 'happens'], tags=[270]),
#  TaggedDocument(words=['trump', 'right', 'violent', 'crime', 'rise', 'major', 'cities'], tags=[271]),
#  TaggedDocument(words=['thank', 'green', 'bay', 'wisconsin', 'governor', 'mike_pence', 'back', 'soon', 'trumppence16', 'maga'], tags=[272]),
#  TaggedDocument(words=['let', 'hillary', 'clinton', 'trumppence16'], tags=[273]),
#  TaggedDocument(words=['plane', 'saw', 'television', 'hostage', 'plane', 'geneva', 'switzerland', 'plane', 'carrying', '400', 'million', 'cash', 'going', 'iran'], tags=[274]),
#  TaggedDocument(words=['president', 'obama', 'refuses', 'answer', 'question', 'iran', 'terror', 'funding', 'dodge', 'questions', 'president'], tags=[275]),
#  TaggedDocument(words=['obama', 'disastrous', 'judgment', 'gave', 'us', 'isis', 'rise', 'iran', 'worst', 'economic', 'numbers', 'since', 'great', 'depression'], tags=[276]),
#  TaggedDocument(words=['president', 'obama', 'ask', 'dnc', 'rigged', 'election', 'bernie'], tags=[277]),
#  TaggedDocument(words=['happy', '226th', 'birthday', 'united', 'states', 'coast', 'guard', 'thank', 'uscg', 'coastguardday'], tags=[278]),
#  TaggedDocument(words=['thank', 'amazing', 'law', 'enforcement', 'officers', 'today', 'daytona', 'beach', 'florida', 'lesm', 'maga'], tags=[279]),
#  TaggedDocument(words=['incompetent', 'secretary', 'state', 'hillary', 'clinton', 'one', 'started', 'talks', 'give', '400', 'million', 'dollars', 'cash', 'iran', 'scandal'], tags=[280]),
#  TaggedDocument(words=['great', 'unity', 'campaign', 'perhaps', 'greater', 'ever', 'want', 'thank', 'everyone', 'tremendous', 'support', 'beat', 'crooked'], tags=[281]),
#  TaggedDocument(words=['president', 'obama', 'go', 'perhaps', 'worst', 'president', 'history', 'united', 'states'], tags=[282]),
#  TaggedDocument(words=['washington', 'post', 'calls', 'crookedhillary', 'really', 'pathological', 'liar', 'watch', 'nose', 'grow'], tags=[283]),
#  TaggedDocument(words=['great', 'afternoon', 'ohio', 'great', 'evening', 'pennsylvania', 'departing', 'see', 'tomorrow', 'virginia'], tags=[284]),
#  TaggedDocument(words=['leaving', 'mechanicsburg', 'pa', 'incredible', 'crowd', 'enthusiastic', 'back', 'soon', 'maga'], tags=[285]),
#  TaggedDocument(words=['cnn', 'segment', 'hillary', 'plan', 'increase', 'syrian', 'refugees', '550', 'much', 'cost'], tags=[286]),
#  TaggedDocument(words=['hillary', 'clinton', 'raked', 'money', 'regimes', 'horribly', 'oppress', 'women', 'gays', 'refuses', 'speak', 'radical', 'islam'], tags=[287]),
#  TaggedDocument(words=['hillary', 'whose', 'decisions', 'led', 'deaths', 'many', 'accepted', 'business', 'linked', 'isis', 'silence', 'cnn'], tags=[288]),
#  TaggedDocument(words=['crooked', 'hillary', 'clinton', '100', 'owned', 'donors', 'imwithyou', 'maga'], tags=[289]),
#  TaggedDocument(words=['thank', 'oklahoma', 'virginia', 'makeamericagreatagain', 'imwithyou'], tags=[290]),
#  TaggedDocument(words=['people', 'believe', 'cnn', 'days', 'almost', 'little', 'believe', 'hillary', 'really', 'saying', 'something'], tags=[291]),
#  TaggedDocument(words=['cnn', 'send', 'cameras', 'border', 'show', 'massive', 'unreported', 'crisis', 'unfolding', 'worried', 'hurt', 'hillary'], tags=[292]),
#  TaggedDocument(words=['see', 'stories', 'cnn', 'clinton', 'foundation', 'corruption', 'hillary', 'pay', 'play', 'state', 'department'], tags=[293]),
#  TaggedDocument(words=['cnn', 'soon', 'least', 'trusted', 'name', 'news', 'continue', 'press', 'shop', 'hillary', 'clinton'], tags=[294]),
#  TaggedDocument(words=['story', 'mr', 'khan', 'place', 'interviews', 'rather', 'radical', 'islamic', 'terrorism', 'get', 'smart'], tags=[295]),
#  TaggedDocument(words=['wow', 'unbelievable', 'distorted', 'one', 'sided', 'biased', 'media', 'us', 'failing', 'nytimes', 'joke', 'cnn', 'laughable'], tags=[296]),
#  TaggedDocument(words=['realjameswoods', 'without', 'absolutely', 'owning', 'liberal', 'media', 'hillaryclinton', 'stand', 'chance', 'voterfraud', 'msm', 'hope'], tags=[297]),
#  TaggedDocument(words=['dishonest', 'media', 'fawning', 'democratic', 'convention', 'wonder', 'speech', 'millions', 'viewers', 'crooked'], tags=[298]),
#  TaggedDocument(words=['viciously', 'attacked', 'mr', 'khan', 'democratic', 'convention', 'allowed', 'respond', 'hillary', 'voted', 'iraq', 'war'], tags=[299]),
#  TaggedDocument(words=['captain', 'khan', 'killed', '12', 'years', 'ago', 'hero', 'radical', 'islamic', 'terror', 'weakness', 'leaders', 'eradicate'], tags=[300]),
#  TaggedDocument(words=['nielson', 'media', 'research', 'final', 'numbers', 'acceptance', 'speech', 'trump', '32', '2', 'million', 'clinton', '27', '8', 'million', 'thank'], tags=[301]),
#  TaggedDocument(words=['thank', 'television', 'viewers', 'made', 'speech', 'republican', 'national', 'convention', '1', 'crooked', 'hillary', 'dems'], tags=[302]),
#  TaggedDocument(words=['wow', 'nato', 'top', 'commander', 'announced', 'agrees', 'alliance', 'members', 'must', 'pay', 'bills', 'general', 'like'], tags=[303]),
#  TaggedDocument(words=['crooked', 'stop', 'johnstown', 'pennsylvania', 'jobs', 'absolutely', 'decimated', 'dumb', 'politicians', 'drew', 'less', '200', 'bill', 'vp'], tags=[304]),
#  TaggedDocument(words=['crookedhillary', 'obama', 'third', 'term', 'would', 'terrible', 'news', 'economic', 'growth', 'seen'], tags=[305]),
#  TaggedDocument(words=['turned', 'meeting', 'charles', 'david', 'koch', 'much', 'better', 'meet', 'puppets', 'politics', 'much', 'better'], tags=[306]),
#  TaggedDocument(words=['crooked', 'hillary', 'clinton', 'soft', 'crime', 'supports', 'open', 'borders', 'wants', 'massive', 'tax', 'hikes', 'formula', 'disaster'], tags=[307]),
#  TaggedDocument(words=['violent', 'crime', 'rising', 'across', 'united', 'states', 'yet', 'dnc', 'convention', 'ignored', 'crime', 'reduction', 'one', 'top', 'priorities'], tags=[308]),
#  TaggedDocument(words=['american', 'homeownership', 'rate', 'q2', '2016', '62', '9', 'lowest', 'rate', '51yrs', 'bring', 'back', 'american', 'dream'], tags=[309]),
#  TaggedDocument(words=['patrioticpepe', 'realdonaldtrump', 'trump', 'unite', 'america', 'fix', 'obama', 'mistakes', 'trump2016'], tags=[310]),
#  TaggedDocument(words=['usual', 'hillary', 'dems', 'trying', 'rig', 'debates', '2', 'major', 'nfl', 'games', 'last', 'time', 'bernie', 'unacceptable'], tags=[311]),
#  TaggedDocument(words=['crookedhillary', 'job', 'application'], tags=[312]),
#  TaggedDocument(words=['hillary', 'clinton', 'given', 'national', 'security', 'briefings', 'lose', 'cannon', 'extraordinarily', 'bad', 'judgement', 'insticts'], tags=[313]),
#  TaggedDocument(words=['thank', 'amazing', 'law', 'enforcement', 'officers', 'colorado', 'makeamericagreatagain', 'lesm'], tags=[314]),
#  TaggedDocument(words=['bernie', 'sanders', 'really', 'thinks', 'crooked', 'hillary', 'clinton'], tags=[315]),
#  TaggedDocument(words=['wow', 'campaign', 'hearing', 'bernie', 'supporters', 'never', 'support', 'crooked', 'hillary', 'sold', 'pick'], tags=[316]),
#  TaggedDocument(words=['hillary', 'clinton', 'america', 'things', 'get', 'worse', 'trumppence16'], tags=[317]),
#  TaggedDocument(words=['crooked', 'hillary', 'said', 'handle', 'rough', 'tumble', 'political', 'campaign', 'really', 'beat', '16', 'people', 'beating'], tags=[318]),
#  TaggedDocument(words=['crooked', 'hillary', 'clinton', 'mentioned', '22', 'times', 'long', 'boring', 'speech', 'many', 'statements', 'lies', 'fabrications'], tags=[319]),
#  TaggedDocument(words=['anncoulter', 'believe', 'science', 'dem', 'code', 'shutting', 'coal', 'mines', 'steel', 'plants', 'remaining', 'manufacturing'], tags=[320]),
#  TaggedDocument(words=['two', 'policemen', 'shot', 'san', 'diego', 'one', 'dead', 'getting', 'worse', 'people', 'want', 'law', 'order'], tags=[321]),
#  TaggedDocument(words=['crooked', 'hillary', 'clinton', 'made', 'facts', 'forgot', 'mention', 'many', 'problems', 'country', 'average', 'scream'], tags=[322]),
#  TaggedDocument(words=['one', 'worse', 'judgement', 'hillary', 'clinton', 'corruption', 'devastation', 'follows', 'wherever', 'goes'], tags=[323]),
#  TaggedDocument(words=['hillary', 'wars', 'middle', 'east', 'unleashed', 'destruction', 'terrorism', 'isis', 'across', 'world'], tags=[324]),
#  TaggedDocument(words=['hillary', 'vision', 'borderless', 'world', 'working', 'people', 'power', 'jobs', 'safety'], tags=[325]),
#  TaggedDocument(words=['hillary', 'never', 'reform', 'wall', 'street', 'owned', 'wall', 'street'], tags=[326]),
#  TaggedDocument(words=['way', 'life', 'threat', 'radical', 'islam', 'hillary', 'clinton', 'even', 'bring', 'say', 'words'], tags=[327]),
#  TaggedDocument(words=['hillary', 'refusal', 'mention', 'radical', 'islam', 'pushes', '550', 'increase', 'refugees', 'proof', 'unfit', 'lead', 'country'], tags=[328]),
#  TaggedDocument(words=['median', 'household', 'income', 'middle', 'class', 'since', 'obama', 'took', 'office', 'go', 'clinton'], tags=[329]),
#  TaggedDocument(words=['vote', 'clinton', 'kaine', 'vote', 'tpp', 'nafta', 'high', 'taxes', 'radical', 'regulation', 'massive', 'influx', 'refugees'], tags=[330]),
# ...
#  TaggedDocument(words=['gene70', 'realdonaldtrump', 'real', 'person', 'year', 'wow'], tags=[891]),
#  TaggedDocument(words=['bernie', 'sanders', 'says', 'hillary', 'clinton', 'unqualified', 'president', 'based', 'decision', 'making', 'ability', 'go', 'along'], tags=[892]),
#  TaggedDocument(words=['shame', 'person', 'far', 'delegates', 'many', 'millions', 'votes', 'anyone', 'else', 'still', 'must', 'fight'], tags=[893]),
#  TaggedDocument(words=['lilrachiepoo', 'realdonaldtrump', 'thank', 'mr', 'trump', 'personal', 'financial', 'sacrifices', 'journey', 'makeamericagreatagain'], tags=[894]),
#  TaggedDocument(words=['redneckgp', 'haters', 'stop', 'trashing', 'candidate', 'realdonaldtrump', 'put', 'america', 'first', 'trump'], tags=[895]),
#  TaggedDocument(words=['kirstiealley', 'hello', 'boys', 'formal', 'endorsement', 'realdonaldtrump', 'woman', 'last', 'checked', 'rudy', 'amazing'], tags=[896]),
#  TaggedDocument(words=['cam', 'reports', 'rnc', 'received', '1', 'million', 'postcards', 'far', 'get', 'info', 'post', 'anncoulter'], tags=[897]),
#  TaggedDocument(words=['nobody', 'beats', 'national', 'security'], tags=[898]),
#  TaggedDocument(words=['looks', 'like', 'right', 'nato', 'doubt'], tags=[899]),
#  TaggedDocument(words=['r_u_ok_uk', 'realdonaldtrump', 'glozee1', 'paulmanafort', 'cnn', 'danscavino', 'vote', 'trump', 'save', 'west', 'become', 'like', 'europe', 'wakeupamerica'], tags=[900]),
#  TaggedDocument(words=['great', 'new', 'york', 'catching', 'many', 'things', 'remember', 'still', 'running', 'major', 'business', 'campaign', 'loving'], tags=[901]),
#  TaggedDocument(words=['dicristo13', 'realdonaldtrump', 'let', 'policy', 'speeches', 'immigration', 'economy', 'foreign', 'policy', 'nato'], tags=[902]),
#  TaggedDocument(words=['genie115', 'makeamericagreatagain', 'realdonaldtrump', 'rt'], tags=[903]),
#  TaggedDocument(words=['ted', 'cruz', 'attacked', 'new', 'yorkers', 'new', 'york', 'values', 'forget'], tags=[904]),
#  TaggedDocument(words=['unbelievable', 'evening', 'made', 'speech', 'front', '17', '000', 'amazing', 'new', 'yorkers', 'bethpage', 'long', 'island', 'great', 'home'], tags=[905]),
#  TaggedDocument(words=['great', 'back', 'home', 'looking', 'forward', 'great', 'rally', 'tonight', 'bethpage', 'long', 'island'], tags=[906]),
#  TaggedDocument(words=['good', 'morning', 'wisconsin', 'polls', 'open', 'votetrump', 'today', 'makeamericagreatagain'], tags=[907]),
#  TaggedDocument(words=['foxnews', 'scottbaio', 'donaldtrump', 'guy', 'think', 'nerve', 'attack', 'fight'], tags=[908]),
#  TaggedDocument(words=['leaving', 'superior', 'wisconsin', 'thank', 'trump2016', 'wiprimary'], tags=[909]),
#  TaggedDocument(words=['wow', 'great', 'news', 'wisconsin', 'made', 'two', 'speeches', 'big', 'one', 'coming', 'tonight', 'thank'], tags=[910]),
#  TaggedDocument(words=['interviewed', 'seanhannity', 'foxnews', 'wisconsin', 'tonight', 'wife', 'melania', 'join', 'entire', 'show'], tags=[911]),
#  TaggedDocument(words=['great', 'day', 'wisconsin', 'many', 'stops', 'many', 'great', 'people', 'melania', 'joining', 'monday', 'big', 'crowds', 'make', 'america', 'great'], tags=[912]),
#  TaggedDocument(words=['great', 'night', 'west', 'allis', 'wisconsin', 'thank', 'votetrumpwi', 'wiprimary'], tags=[913]),
#  TaggedDocument(words=['thank', 'miss', 'katie', 'diner', 'makeamericagreatagain', 'trump2016'], tags=[914]),
#  TaggedDocument(words=['thank', 'new', 'york', 'pennsylvania', 'makeamericagreatagain', 'trump2016'], tags=[915]),
#  TaggedDocument(words=['gopjenna', 'care', 'game', 'care', 'people', 'exactly', 'people', 'love', 'much', 'trump2016'], tags=[916]),
#  TaggedDocument(words=['thank', 'trump2016', 'wiprimary'], tags=[917]),
#  TaggedDocument(words=['margee11', 'wisconsin', 'vote', 'smart', 'tedcruz', 'records', 'sealed', 'hiding', 'save', 'america', 'realdonaldtrump'], tags=[918]),
#  TaggedDocument(words=['thank', 'eau', 'claire', 'wisconsin', 'votetrump', 'tuesday', 'april', '5th', 'make', 'america', 'great'], tags=[919]),
#  TaggedDocument(words=['foxnews', 'ashamed', 'allowing', 'experts', 'explain', 'make', 'nuclear', 'attack'], tags=[920]),
#  TaggedDocument(words=['wisconsin', 'suffered', 'great', 'loss', 'jobs', 'trade', 'win', 'bad', 'things', 'happening', 'rapidly', 'reversed'], tags=[921]),
#  TaggedDocument(words=['wisconsin', 'election', 'jobs', 'trade', 'immigration', 'big', 'factors', 'bring', 'jobs', 'back', 'home', 'make', 'great', 'deals'], tags=[922]),
#  TaggedDocument(words=['megynkelly', 'stopped', 'covering', 'show', 'ratings', 'would', 'drop', 'like', 'rock', 'interview', 'ac360', 'beat', 'millions'], tags=[923]),
#  TaggedDocument(words=['possible', 'megynkelly', 'cover', 'anyone', 'donald', 'trump', 'terrible', 'show', 'totally', 'misrepresents', 'words', 'positions', 'bad'], tags=[924]),
#  TaggedDocument(words=['believe', 'ted', 'cruz', 'killing', 'country', 'trade', 'long', 'put', 'wisconsin', 'ad', 'talking', 'trade'], tags=[925]),
#  TaggedDocument(words=['must', 'build', 'great', 'wall', 'mexico', 'united', 'states'], tags=[926]),
#  TaggedDocument(words=['1st', 'time', 'american', 'history', 'america', '16', '500', 'border', 'patrol', 'agents', 'issue', 'presidential', 'primary', 'endorsement', 'thank'], tags=[927]),
#  TaggedDocument(words=['national', 'border', 'patrol', 'council', 'nbpc', 'said', 'open', 'border', 'biggest', 'physical', 'economic', 'threat', 'facing', 'american', 'people'], tags=[928]),
#  TaggedDocument(words=['club', 'growth', 'said', 'ad', '465', 'delegates', 'cruz', 'plus', '143', 'delegates', 'kasich', '739', 'delegates', 'try'], tags=[929]),
#  TaggedDocument(words=['club', 'growth', 'asked', '1', '000', '000', 'extortion', 'attempt', 'put', 'wisconsin', 'ad', 'incorrect', 'math', 'dumb', 'group'], tags=[930]),
#  TaggedDocument(words=['thank', 'america', 'trump2016', 'makeamericagreatagain'], tags=[931]),
#  TaggedDocument(words=['thank', 'wisconsin', 'votetrump', 'next', 'tuesday', 'april', '5th', 'wiprimary'], tags=[932]),
#  TaggedDocument(words=['nice', 'meeting', 'reince', 'priebus', 'gop', 'looking', 'forward', 'bringing', 'party', 'together', 'happen'], tags=[933]),
#  TaggedDocument(words=['trump', 'doctrine', 'peace', 'strength', 'trump2016'], tags=[934]),
#  TaggedDocument(words=['susanbirchfiel1', 'nothing', 'say', 'change', 'mind', 'woman', 'realdonaldtrump'], tags=[935]),
#  TaggedDocument(words=['gearssuxs', 'loudobbsnews', 'realdonaldtrump', 'democrat', 'switch', 'republican', 'vote', 'trump', 'primary', 'great'], tags=[936]),
#  TaggedDocument(words=['thank', 'appleton', 'wisconsin', 'wiprimary', 'trump2016'], tags=[937]),
#  TaggedDocument(words=['congratulations', 'cnn', 'wisdom', 'pick', 'trump', 'makeamericagreatagain', 'trump2016'], tags=[938]),
#  TaggedDocument(words=['please', 'keep', 'thoughts', 'prayers', 'melissa', 'young', 'miss', 'wisconsin', '2005'], tags=[939]),
#  TaggedDocument(words=['thank', 'new', 'york', 'makeamericagreatagain', 'trump2016'], tags=[940]),
#  TaggedDocument(words=['davidgregory', 'got', 'thrown', 'tv', 'nbc', 'fired', 'like', 'dog', 'cnn', 'nasty', 'nice'], tags=[941]),
#  TaggedDocument(words=['final', 'announced', 'great', 'state', 'mo', 'trump', 'wins', 'new', 'certified', 'show', '365', 'vote', 'increase', 'least', '12', 'delegates'], tags=[942]),
#  TaggedDocument(words=['reporter', 'touching', 'leave', 'news', 'conference', 'hand'], tags=[943]),
#  TaggedDocument(words=['victory', 'press', 'conference', 'allowed', 'grab', 'shout', 'questions', 'press', 'charges'], tags=[944]),
#  TaggedDocument(words=['wow', 'corey', 'lewandowski', 'campaign', 'manager', 'decent', 'man', 'charged', 'assaulting', 'reporter', 'look', 'tapes', 'nothing'], tags=[945]),
#  TaggedDocument(words=['millions', 'votes', 'hundreds', 'dels', 'cruz', 'kasich', 'yet', 'treated', 'properly', 'republican', 'party', 'rnc'], tags=[946]),
#  TaggedDocument(words=['wow', 'cnn', 'nothing', 'opponents', 'shows', 'really', 'one', 'sided', 'unfair', 'reporting', 'maybe', 'town', 'hall', 'tonight'], tags=[947]),
#  TaggedDocument(words=['need', 'secure', 'borders', 'asap', 'games', 'must', 'smart', 'tough', 'vigilant', 'make', 'america', 'great', 'make', 'america', 'strong'], tags=[948]),
#  TaggedDocument(words=['lyin', 'ted', 'already', 'beaten', 'debates', 'way', 'ahead', 'votes', 'delegates', 'focus', 'jobs', 'illegal', 'imm'], tags=[949]),
#  TaggedDocument(words=['detainee', 'released', 'gitmo', 'killed', 'american', 'called', 'leaders', 'ever', 'learn'], tags=[950]),
#  TaggedDocument(words=['united', 'states', 'continue', 'make', 'bad', 'one', 'sided', 'trade', 'deals', 'many', 'jobs', 'give'], tags=[951]),
#  TaggedDocument(words=['see', 'lyin', 'ted', 'even', 'dailybeast', 'fan', 'mine', 'says', 'story', 'came', 'rubio', 'trump'], tags=[952]),
#  TaggedDocument(words=['show', 'unfair', 'republican', 'primary', 'politics', 'state', 'louisiana', 'get', 'less', 'delegates', 'cruz', 'lawsuit', 'coming'], tags=[953]),
#  TaggedDocument(words=['another', 'radical', 'islamic', 'attack', 'time', 'pakistan', 'targeting', 'christian', 'women', 'children', 'least', '67', 'dead', '400', 'injured', 'alone', 'solve'], tags=[954]),
#  TaggedDocument(words=['happy', 'easter', 'great', 'day'], tags=[955]),
#  TaggedDocument(words=['statement', 'nato', 'obsolete', 'disproportionately', 'expensive', 'unfair', 'finally', 'receiving', 'plaudits'], tags=[956]),
#  TaggedDocument(words=['remember', 'candidate', 'self', 'funding', 'given', 'little', 'credit', 'voters', 'bought', 'like', 'others'], tags=[957]),
#  TaggedDocument(words=['believe', 'foxnews', 'polls', 'another', 'phony', 'hit', 'job', 'beat', 'hillary', 'clinton', 'easily', 'general', 'election'], tags=[958]),
#  TaggedDocument(words=['wisconsin', 'economy', 'poorly', 'like', 'everywhere', 'else', 'jobs', 'leaving', 'make', 'economy', 'strong', 'bring', 'jobs'], tags=[959]),
#  TaggedDocument(words=['nobody', 'protect', 'nation', 'like', 'donald', 'trump', 'military', 'greatly', 'strengthened', 'borders', 'strong', 'illegals'], tags=[960]),
#  TaggedDocument(words=['lyin', 'ted', 'cruz', 'trying', 'convince', 'prople', 'problems', 'national', 'enq', 'caused', 'nothing', 'story'], tags=[961]),
#  TaggedDocument(words=['press', 'going', 'way', 'convince', 'people', 'like', 'respect', 'women', 'know', 'opposite'], tags=[962]),
#  TaggedDocument(words=['media', 'women', 'wow', 'tough', 'business', 'nobody', 'respect', 'women', 'donald', 'trump'], tags=[963]),
#  TaggedDocument(words=['tytan01', 'dear', 'cnn', 'quick', 'google', 'twitter', 'search', '15', '000', 'women', 'groups', 'supporting', 'donaldtrump', 'stop', 'lying'], tags=[964]),
#  TaggedDocument(words=['top', 'suspect', 'paris', 'massacre', 'salah', 'abdeslam', 'also', 'knew', 'brussels', 'attack', 'longer', 'talking', 'weak', 'leaders', 'ridiculous', 'laws'], tags=[965]),
#  TaggedDocument(words=['wow', 'released', '67', 'million', 'negative', 'ads', 'spent', 'still', 'number', 'one', 'lot'], tags=[966]),
#  TaggedDocument(words=['start', 'fight', 'lyin', 'ted', 'cruz', 'gq', 'cover', 'pic', 'melania', 'knew', 'pac', 'putting', 'hence', 'lyin', 'ted'], tags=[967]),
#  TaggedDocument(words=['big', 'federal', 'lawsuit', 'similar', 'certain', 'ways', 'trump', 'case', 'press', 'refuses', 'write', 'lost', 'monster', 'story'], tags=[968]),
#  TaggedDocument(words=['europe', 'must', 'immediately', 'stop', 'taking', 'people', 'syria', 'destruction', 'civilization', 'know', 'sad'], tags=[969]),
#  TaggedDocument(words=['announced', 'many', '5000', 'isis', 'fighters', 'infiltrated', 'europe', 'also', 'many', 'told', 'alone', 'fix', 'problem'], tags=[970]),
#  TaggedDocument(words=['amazing', 'often', 'right', 'criticized', 'media', 'illegal', 'immigration', 'take', 'oil', 'build', 'wall', 'muslims', 'nato'], tags=[971]),
#  TaggedDocument(words=['remember', 'recently', 'said', 'brussels', 'hell', 'hole', 'mess', 'failing', 'nytimes', 'wrote', 'critical', 'article', 'right'], tags=[972]),
#  TaggedDocument(words=['don_vito_08', 'picture', 'worth', 'thousand', 'words', 'realdonaldtrump', 'lyingted', 'nevercruz', 'melaniatrump'], tags=[973]),
#  TaggedDocument(words=['make', 'america', 'great'], tags=[974]),
#  TaggedDocument(words=['think', 'jeb', 'endorsement', 'hurts', 'lyin', 'ted', 'jeb', 'spent', '150', '000', '000', 'got', 'nothing', 'spent', 'fraction', 'first'], tags=[975]),
#  TaggedDocument(words=['best', 'far', 'fighting', 'terror', 'one', 'right', 'beginning', 'lyin', 'ted', 'others', 'copying'], tags=[976]),
#  TaggedDocument(words=['watched', 'hillary', 'deliver', 'prepackaged', 'speech', 'terror', 'office', 'fighting', 'terror', '20', 'years', 'look'], tags=[977]),
#  TaggedDocument(words=['low', 'energy', 'jeb', 'bush', 'endorsed', 'man', 'truly', 'hates', 'lyin', 'ted', 'cruz', 'honestly', 'blame', 'jeb', 'drove', 'oblivion'], tags=[978]),
#  TaggedDocument(words=['lyin', 'ted', 'cruz', 'steals', 'foreign', 'policy', 'lines', 'michael', 'douglas', 'another', 'dishonest', 'politician'], tags=[979]),
#  TaggedDocument(words=['lyin', 'ted', 'cruz', 'denied', 'anything', 'model', 'photo', 'post', 'melania', 'call', 'lyin', 'ted'], tags=[980]),
#  TaggedDocument(words=['hopefully', 'republican', 'party', 'come', 'together', 'big', 'win', 'november', 'paving', 'way', 'many', 'great', 'supreme', 'court', 'justices'], tags=[981]),
#  TaggedDocument(words=['much', 'bigger', 'win', 'anticipated', 'arizona', 'thank', 'never', 'forget'], tags=[982]),
#  TaggedDocument(words=['incompetent', 'hillary', 'despite', 'horrible', 'attack', 'brussels', 'today', 'wants', 'borders', 'weak', 'open', 'let', 'muslims', 'flow', 'way'], tags=[983]),
#  TaggedDocument(words=['lyin', 'ted', 'cruz', 'used', 'picture', 'melania', 'shoot', 'ad', 'careful', 'lyin', 'ted', 'spill', 'beans', 'wife'], tags=[984]),
#  TaggedDocument(words=['pres', 'obama', 'leave', 'baseball', 'game', 'cuba', 'immediately', 'get', 'home', 'washington', 'potus', 'serious', 'emergency', 'belongs'], tags=[985]),
#  TaggedDocument(words=['obama', 'others', 'weak', 'politically', 'correct', 'terror', 'groups', 'forming', 'getting', 'stronger', 'shame'], tags=[986]),
#  TaggedDocument(words=['heart', 'prayers', 'go', 'victims', 'terrible', 'brussels', 'tragedy', 'madness', 'must', 'stopped', 'stop'], tags=[987]),
#  TaggedDocument(words=['watch', 'clip', 'earlier', 'year', 'time', 'time', 'right', 'terrorism', 'time', 'get', 'tough'], tags=[988]),
#  TaggedDocument(words=['proven', 'far', 'correct', 'terrorism', 'anybody', 'even', 'close', 'hopefully', 'az', 'ut', 'voting', 'today'], tags=[989]),
#  TaggedDocument(words=['make', 'america', 'great'], tags=[990]),
#  TaggedDocument(words=['president', 'obama', 'looks', 'sounds', 'ridiculous', 'making', 'speech', 'cuba', 'especially', 'shadows', 'brussels', 'treated', 'badly'], tags=[991]),
#  TaggedDocument(words=['remember', 'beautiful', 'safe', 'place', 'brussels', 'anymore', 'different', 'world', 'must', 'vigilant', 'smart'], tags=[992]),
#  TaggedDocument(words=['barrong510', 'realdonaldtrump', 'media', 'corrupt', 'people', 'fighting'], tags=[993]),
#  TaggedDocument(words=['wow', 'president', 'obama', 'landed', 'cuba', 'big', 'deal', 'raul', 'castro', 'even', 'greet', 'greeted', 'pope', 'others', 'respect'], tags=[994]),
#  TaggedDocument(words=['highly', 'overrated', 'anchor', 'megynkelly', 'allowed', 'constantly', 'say', 'bad', 'things', 'show', 'fight', 'back', 'wrong'], tags=[995]),
#  TaggedDocument(words=['protesters', 'blocked', 'major', 'highway', 'yesterday', 'delaying', 'entry', 'rally', 'arizona', 'hours', 'media', 'blames', 'supporters'], tags=[996]),
#  TaggedDocument(words=['horrendous', 'protesters', 'scream', 'curse', 'punch', 'shut', 'roads', 'doors', 'rallies', 'never', 'blamed', 'media', 'sad'], tags=[997]),
#  TaggedDocument(words=['rallies', 'utah', 'arizona', 'great', 'tremendous', 'crowds', 'spirit', 'returned', 'going', 'back', 'soon'], tags=[998]),
#  TaggedDocument(words=['jojo2foxy', 'trump', 'afraid', 'anything', 'anyone', 'president', 'usa', 'needs', 'unite', 'us', 'knock', 'socks', 'enemies'], tags=[999]),
#  ...]

# %%
modeldoc2vec = Doc2Vec(tag_words, vector_size=20, window=5, min_count=1, workers=-1, epochs = 20)

# %%
len(modeldoc2vec.wv.vocab)
# Out:
# 17524

# %%
pickle.dump(modeldoc2vec, open('Doc2VecModelFinal.pkl','wb'))

# %%
Doc2VecModelFinal = pickle.load(open('Doc2VecModelFinal.pkl','rb'))

# %%
len(Doc2VecModelFinal.wv.vocab)
# Out:
# 17524

# %%
txt_example = ["Here is my statement"]
example_result_model = Doc2VecModelFinal.docvecs.most_similar(positive=[Doc2VecModelFinal.infer_vector(txt_example)], topn=20)
example_result_model
# Out:
# [(4557, 0.7610223293304443),
#  (2548, 0.6945040225982666),
#  (11531, 0.6928262710571289),
#  (14732, 0.6885021924972534),
#  (1086, 0.6813532114028931),
#  (9943, 0.6791173815727234),
#  (7254, 0.6784337162971497),
#  (746, 0.6766431331634521),
#  (4638, 0.6680054664611816),
#  (3816, 0.6561073064804077),
#  (2787, 0.6557133793830872),
#  (6053, 0.6498664617538452),
#  (14802, 0.6451649069786072),
#  (2774, 0.6428327560424805),
#  (1242, 0.642427384853363),
#  (5237, 0.6380745768547058),
#  (14322, 0.6366419196128845),
#  (12037, 0.6304845213890076),
#  (15671, 0.6246137022972107),
#  (5926, 0.6220338940620422)]

# %%
example_of_string = "Is this really America"

# %%
def get_similarities(model, sentence):
    example_result_model = model.docvecs.most_similar(positive=[model.infer_vector([sentence])], topn=20)
    return example_result_model

# %%
get_similarities(Doc2VecModelFinal,example_of_string)
# Out:
# [(11095, 0.7411857843399048),
#  (6285, 0.7329152822494507),
#  (3625, 0.7183679342269897),
#  (12613, 0.7090334296226501),
#  (16201, 0.7071962356567383),
#  (5221, 0.6938114166259766),
#  (12648, 0.6913438439369202),
#  (6150, 0.6909806728363037),
#  (5558, 0.6654672622680664),
#  (1633, 0.6626005172729492),
#  (9702, 0.661744236946106),
#  (475, 0.6605814695358276),
#  (9217, 0.6595841646194458),
#  (13942, 0.6578094363212585),
#  (14652, 0.6563979387283325),
#  (5029, 0.6511921286582947),
#  (3993, 0.6398176550865173),
#  (1749, 0.637171745300293),
#  (1205, 0.6357545256614685),
#  (15638, 0.6327559947967529)]

# %%
def get_tweet(resultsimilarity):
    tweet_similar = []
    for elem in resultsimilarity:
        tweet_similar.append({'id': elem[0],'tweets': df.text[elem[0]],'score': elem[1]})
    #print(tweet_similar)
    return tweet_similar

# %%
get_tweet(example_result_model)
# Out:
# [{'id': 4557,
#   'tweets': '"@Boarcane: DonaldTrump We need you to run and WIN! A true patriot with only the country\'s best interest at heart. http://twitter.com/Boarcane/status/578358741441052673/photo/1pic.twitter.com/6LIcHFMx2G\xa0',
#   'score': 0.7610223293304443},
#  {'id': 2548,
#   'tweets': 'Ben Carson was speaking in general terms as to what he would do if confronted with a gunman, and was not criticizing the victims. Not fair!',
#   'score': 0.6945040225982666},
#  {'id': 11531,
#   'tweets': '.@DennisRodman re @Omarosa is right, she’s becoming predictable.',
#   'score': 0.6928262710571289},
#  {'id': 14732,
#   'tweets': 'A friend is one who has the same enemies as you have. -- Abraham Lincoln',
#   'score': 0.6885021924972534},
#  {'id': 1086,
#   'tweets': 'MAKE AMERICA GREAT AGAIN!',
#   'score': 0.6813532114028931},
#  {'id': 9943,
#   'tweets': "The ties, shirts and suits at Macy's are doing fantastically well-check out the new designs and low prices-nothing better!",
#   'score': 0.6791173815727234},
#  {'id': 7254,
#   'tweets': '"@TedatACA: I concur with @realDonaldTrump on Pinehurst. IMO: Those blasts from sandy areas looked like IEDs exploding In Kandahar Province.',
#   'score': 0.6784337162971497},
#  {'id': 746,
#   'tweets': 'It is only the people that were never asked to be VP that tell the press that they will not take the position.',
#   'score': 0.6766431331634521},
#  {'id': 4638,
#   'tweets': 'The mark of a great player is in his ability to come back. The great champions have all come back from defeat. -- Sam Snead',
#   'score': 0.6680054664611816},
#  {'id': 3816,
#   'tweets': '"@obadafidii: Trump: \'I Want to Make the Country Great Again\' http://smar.ws/N9SFu\xa0 #SmartNews"',
#   'score': 0.6561073064804077},
#  {'id': 2787,
#   'tweets': 'Look forward to being in DC tomorrow—big crowd expected for our protest against the truly stupid nuclear deal we are making with Iran.',
#   'score': 0.6557133793830872},
#  {'id': 6053,
#   'tweets': '"@leksi0731: If @realDonaldTrump ran for president he would have my vote!"',
#   'score': 0.6498664617538452},
#  {'id': 14802,
#   'tweets': '.@Lord_Sugar  If you think ugly windmills are good for Scotland you are an even worse businessman than I thought...',
#   'score': 0.6451649069786072},
#  {'id': 2774,
#   'tweets': 'A letter to @CNN President Jeff Zucker-pic.twitter.com/HKUYv9tFRm',
#   'score': 0.6428327560424805},
#  {'id': 1242,
#   'tweets': 'Just finished two major speeches in South Carolina. Big crowds, great people. Going for a third now!',
#   'score': 0.642427384853363},
#  {'id': 5237,
#   'tweets': 'Looking forward to being honored with the prestigious ‘Friend of Israel’ award at the @Algemeiner Gala Dinner https://gjcf.net/gala/join/\xa0',
#   'score': 0.6380745768547058},
#  {'id': 14322,
#   'tweets': 'The Afghan Security Forces who we are training have killed 52 U.S. soldiers http://goo.gl/xdoqd\xa0 Time to get out of there!',
#   'score': 0.6366419196128845},
#  {'id': 12037,
#   'tweets': 'Can you imagine if @billmaher said about Obama what he said about me (orangutan etc)—the press would run him out of the country...',
#   'score': 0.6304845213890076},
#  {'id': 15671,
#   'tweets': "One of the best moves I ever made was staying out of last decade's artificial real estate boom. But I used the downturn to my advantage.",
#   'score': 0.6246137022972107},
#  {'id': 5926,
#   'tweets': '"@ronmeier123: @foxandfriends You are exactly what America needs going forward! MR. TRUMP for President in 2016 is a SMART BET!',
#   'score': 0.6220338940620422}]

# %%
def get_tweet_only(resultsimilarity):
    only_tweet_similar = []
    for elem in resultsimilarity:
        only_tweet_similar.append({'tweets':df.text[elem[0]]})
    #print(tweet_similar)
    return only_tweet_similar

# %%
get_tweet_only(example_result_model)
# Out:
# [{'tweets': '"@Boarcane: DonaldTrump We need you to run and WIN! A true patriot with only the country\'s best interest at heart. http://twitter.com/Boarcane/status/578358741441052673/photo/1pic.twitter.com/6LIcHFMx2G\xa0'},
#  {'tweets': 'Ben Carson was speaking in general terms as to what he would do if confronted with a gunman, and was not criticizing the victims. Not fair!'},
#  {'tweets': '.@DennisRodman re @Omarosa is right, she’s becoming predictable.'},
#  {'tweets': 'A friend is one who has the same enemies as you have. -- Abraham Lincoln'},
#  {'tweets': 'MAKE AMERICA GREAT AGAIN!'},
#  {'tweets': "The ties, shirts and suits at Macy's are doing fantastically well-check out the new designs and low prices-nothing better!"},
#  {'tweets': '"@TedatACA: I concur with @realDonaldTrump on Pinehurst. IMO: Those blasts from sandy areas looked like IEDs exploding In Kandahar Province.'},
#  {'tweets': 'It is only the people that were never asked to be VP that tell the press that they will not take the position.'},
#  {'tweets': 'The mark of a great player is in his ability to come back. The great champions have all come back from defeat. -- Sam Snead'},
#  {'tweets': '"@obadafidii: Trump: \'I Want to Make the Country Great Again\' http://smar.ws/N9SFu\xa0 #SmartNews"'},
#  {'tweets': 'Look forward to being in DC tomorrow—big crowd expected for our protest against the truly stupid nuclear deal we are making with Iran.'},
#  {'tweets': '"@leksi0731: If @realDonaldTrump ran for president he would have my vote!"'},
#  {'tweets': '.@Lord_Sugar  If you think ugly windmills are good for Scotland you are an even worse businessman than I thought...'},
#  {'tweets': 'A letter to @CNN President Jeff Zucker-pic.twitter.com/HKUYv9tFRm'},
#  {'tweets': 'Just finished two major speeches in South Carolina. Big crowds, great people. Going for a third now!'},
#  {'tweets': 'Looking forward to being honored with the prestigious ‘Friend of Israel’ award at the @Algemeiner Gala Dinner https://gjcf.net/gala/join/\xa0'},
#  {'tweets': 'The Afghan Security Forces who we are training have killed 52 U.S. soldiers http://goo.gl/xdoqd\xa0 Time to get out of there!'},
#  {'tweets': 'Can you imagine if @billmaher said about Obama what he said about me (orangutan etc)—the press would run him out of the country...'},
#  {'tweets': "One of the best moves I ever made was staying out of last decade's artificial real estate boom. But I used the downturn to my advantage."},
#  {'tweets': '"@ronmeier123: @foxandfriends You are exactly what America needs going forward! MR. TRUMP for President in 2016 is a SMART BET!'}]
